# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
import json
import numpy as np

pd.options.mode.chained_assignment = None  # default='warn'

#Pull in CSV paths

csvST = "csv data/Stress by State.csv"
stress_data = pd.read_csv(csvST)
stress_df = pd.DataFrame(stress_data)

# %%
stress_clean = stress_df.dropna()
stress_filter = stress_clean.filter(['Event Category', 'Region'])
stress_group = stress_filter.groupby(['Region', 'Event Category']).agg({'Event Category': ['count']})
stress_final = stress_group.reset_index()
stress_final
# Out:
#       Region   Event Category
#                               count
# 0    Alabama   Drugs/Drinking    45
# 1    Alabama              Eat    62
# 2    Alabama       Nothing Q3    84
# 3    Alabama         Other Q3    57
# 4    Alabama  Talk to Friends    90
# ..       ...              ...   ...
# 301  Wyoming              Eat    35
# 302  Wyoming       Nothing Q3    27
# 303  Wyoming         Other Q3    30
# 304  Wyoming  Talk to Friends    27
# 305  Wyoming         Work-out    19
#
# [306 rows x 3 columns]

# %%
stress_dict = stress_final.to_dict('records')
stress_json = json.dumps(stress_dict, indent = 2)
print(stress_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-0e7db96b7b58> in <module>
#       1 stress_dict = stress_final.to_dict('records')
# ----> 2 stress_json = json.dumps(stress_dict, indent = 2)
#       3 print(stress_dict)
#
# ~\anaconda3\envs\PythonData\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~\anaconda3\envs\PythonData\lib\json\encoder.py in encode(self, o)
#     199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# --> 201             chunks = list(chunks)
# ...
